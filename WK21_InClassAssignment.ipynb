# %% [markdown]
# ### In Class Assignment
# #### Angela Spencer - 02/16/2022

# %% [markdown]
# #### 1. Make sure you can get the API from class to work in Azure. Take a screenshot of it working and add the image to a jupyter notebook.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. Loop through the API data in python using the /gdp/"year input" endpoint for your API. What does it look like? Is there a way to alter the html page to simplify what you see?
