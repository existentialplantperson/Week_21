# %% [markdown]
# ###### In Class Notes

# %% [markdown]
# ###### Warm UP

# %%
import re
from nltk.tokenize import regexp_tokenize

# %%
this_string = "Y'all are amazing, and I've loved teaching this class."
pattern = r"\w+'\w+"
hashtags = regexp_tokenize(this_string, pattern)
hashtags
# Out:
# ["Y'all", "I've"]

# %% [markdown]
# ###### Notes

# %% [markdown]
# Intro to Cloud
# - availability - services need to have nearly 100% uptime
# - scalability - services need to increase in amount of size as demands and data increase
# - elasticity - dynamically allocate resources (horizontal and vertical scaling)
# - disaster recovery - data and/or applications are backed up in a different data center and can be spun up in minutes in case of failure
# - accessibility - availability all over the wrold over HTTP or HTTPS
# - security - automated encryption and access control in the provider platform
#
# 3 main providers - Amazon most common, Microsoft, Google least common
# - Alexis like Microsoft because of the support, free tiers, and successful release of new updates and products
#
# -basically renting space rather than owning your own servers
#
# ### API
# - application Programming Interface
# - allows programs to interact with other applications of database
# - connections between programs
#
# ARTICLE TO READ:
# https://nordicapis.com/crud-vs-rest-whats-the-difference/
#
# also look into - https://www.infoq.com/articles/webber-rest-workflow/
#
#
# DISCUSSION:
# CRUD - Create Read Update Delete
# state - is the state of data at a given moment in time in the server
#     - stateful - does retain a record of data and server use
#     - stateless - does not retain a record of use of data
#
# ### Flask APIs
# - Flask is a 'micro web application' framework, you can use it to make simple applications but we are just oging to use it to make APIS
# - framework - sollection of libraries that let developers create scalable maintainable and reliable code by using certain established patterns
# - flask has good documentation and should be referenced for issues
#
# ### localhost
# - no websites can have IP addressed that start with 127, they are reserved for loopback which let you interact with your own web server
# - we test applications in localhost because the computer simulates a webserver when a loopback is triggered

# %% [markdown]
# ![image.png](attachment:image.png)
